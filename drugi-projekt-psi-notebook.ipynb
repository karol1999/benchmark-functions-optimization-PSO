# %%
import numpy as np

# %%
from pyswarms.utils.functions.single_obj import sphere

# %%
from pyswarms.utils.functions.single_obj import rastrigin

# %%
from pyswarms.utils.functions.single_obj import rosenbrock

# %%
from pyswarms.utils.functions.single_obj import ackley

# %%
import pyswarms.backend as P
from pyswarms.backend.topology import Star

# %%
# %load_ext autoreload
# %autoreload 2

# %%
my_topology = Star()

# %%
my_options = {'c1': 0.6, 'c2': 0.3, 'w': 0.4}

# %%
my_swarm = P.create_swarm(n_particles=50, dimensions=10, options=my_options)

# %%
iterations = 100 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm.current_cost = sphere(my_swarm.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm.pbest_cost = sphere(my_swarm.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm.pbest_pos, my_swarm.pbest_cost = P.compute_pbest(my_swarm) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm.pbest_cost) < my_swarm.best_cost:
        my_swarm.best_pos, my_swarm.best_cost = my_topology.compute_gbest(my_swarm)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm.velocity = my_topology.compute_velocity(my_swarm)
    my_swarm.position = my_topology.compute_position(my_swarm)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 1.4848
# Iteracja: 21 | my_swarm.best_cost: 0.8024
# Iteracja: 41 | my_swarm.best_cost: 0.7996
# Iteracja: 61 | my_swarm.best_cost: 0.7996
# Iteracja: 81 | my_swarm.best_cost: 0.7996
# Najlepszy znaleziony koszt: 0.7996
# Najlepsza znaleziona pozycja: [0.27356104 0.27284337 0.26323798 0.35504425 0.18161761 0.31052417
#  0.14228952 0.21253046 0.39616645 0.32125183]

# %%
iterations = 100 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm.current_cost = sphere(my_swarm.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm.pbest_cost = sphere(my_swarm.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm.pbest_pos, my_swarm.pbest_cost = P.compute_pbest(my_swarm) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm.pbest_cost) < my_swarm.best_cost:
        my_swarm.best_pos, my_swarm.best_cost = my_topology.compute_gbest(my_swarm)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm.velocity = my_topology.compute_velocity(my_swarm)
    my_swarm.position = my_topology.compute_position(my_swarm)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 0.8375
# Iteracja: 21 | my_swarm.best_cost: 0.8375
# Iteracja: 41 | my_swarm.best_cost: 0.8375
# Iteracja: 61 | my_swarm.best_cost: 0.8375
# Iteracja: 81 | my_swarm.best_cost: 0.8375
# Najlepszy znaleziony koszt: 0.8375
# Najlepsza znaleziona pozycja: [0.22582631 0.15362977 0.34160872 0.4312552  0.28310125 0.26129921
#  0.27148397 0.41479346 0.2229798  0.12778015]

# %%
iterations = 100 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm.current_cost = sphere(my_swarm.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm.pbest_cost = sphere(my_swarm.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm.pbest_pos, my_swarm.pbest_cost = P.compute_pbest(my_swarm) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm.pbest_cost) < my_swarm.best_cost:
        my_swarm.best_pos, my_swarm.best_cost = my_topology.compute_gbest(my_swarm)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm.velocity = my_topology.compute_velocity(my_swarm)
    my_swarm.position = my_topology.compute_position(my_swarm)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 1.1255
# Iteracja: 21 | my_swarm.best_cost: 0.6626
# Iteracja: 41 | my_swarm.best_cost: 0.6607
# Iteracja: 61 | my_swarm.best_cost: 0.6607
# Iteracja: 81 | my_swarm.best_cost: 0.6607
# Najlepszy znaleziony koszt: 0.6607
# Najlepsza znaleziona pozycja: [0.12656068 0.35548317 0.12540757 0.29028282 0.14985031 0.0654098
#  0.0753894  0.32263414 0.18575052 0.49731095]

# %%
my_topology_rastrigin = Star()

# %%
max_bound = 5.12 * np.ones(2)
min_bound = - max_bound
bounds = (min_bound, max_bound)

# %%
my_options_rastrigin = {'c1': 0.6, 'c2': 0.3, 'w': 0.4}

# %%
my_swarm_rastrigin = P.create_swarm(n_particles=50, dimensions=2, options=my_options, bounds=bounds)

# %%
iterations = 100 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_rastrigin.current_cost = rastrigin(my_swarm_rastrigin.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_rastrigin.pbest_cost = rastrigin(my_swarm_rastrigin.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_rastrigin.pbest_pos, my_swarm_rastrigin.pbest_cost = P.compute_pbest(my_swarm_rastrigin) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_rastrigin.pbest_cost) < my_swarm_rastrigin.best_cost:
        my_swarm_rastrigin.best_pos, my_swarm_rastrigin.best_cost = my_topology_rastrigin.compute_gbest(my_swarm_rastrigin)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_rastrigin.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rastrigin.velocity = my_topology_rastrigin.compute_velocity(my_swarm_rastrigin)
    my_swarm_rastrigin.position = my_topology_rastrigin.compute_position(my_swarm_rastrigin)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_rastrigin.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_rastrigin.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 6.0220
# Iteracja: 21 | my_swarm.best_cost: 0.0515
# Iteracja: 41 | my_swarm.best_cost: 0.0057
# Iteracja: 61 | my_swarm.best_cost: 0.0057
# Iteracja: 81 | my_swarm.best_cost: 0.0057
# Najlepszy znaleziony koszt: 0.0056
# Najlepsza znaleziona pozycja: [-0.00029737  0.00528922]

# %%
iterations = 100 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_rastrigin.current_cost = rastrigin(my_swarm_rastrigin.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_rastrigin.pbest_cost = rastrigin(my_swarm_rastrigin.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_rastrigin.pbest_pos, my_swarm_rastrigin.pbest_cost = P.compute_pbest(my_swarm_rastrigin) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_rastrigin.pbest_cost) < my_swarm_rastrigin.best_cost:
        my_swarm_rastrigin.best_pos, my_swarm_rastrigin.best_cost = my_topology_rastrigin.compute_gbest(my_swarm_rastrigin)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_rastrigin.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rastrigin.velocity = my_topology_rastrigin.compute_velocity(my_swarm_rastrigin)
    my_swarm_rastrigin.position = my_topology_rastrigin.compute_position(my_swarm_rastrigin)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_rastrigin.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_rastrigin.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 0.0034
# Iteracja: 21 | my_swarm.best_cost: 0.0034
# Iteracja: 41 | my_swarm.best_cost: 0.0009
# Iteracja: 61 | my_swarm.best_cost: 0.0009
# Iteracja: 81 | my_swarm.best_cost: 0.0009
# Najlepszy znaleziony koszt: 0.0009
# Najlepsza znaleziona pozycja: [0.0020469  0.00033317]

# %%
iterations = 100 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_rastrigin.current_cost = rastrigin(my_swarm_rastrigin.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_rastrigin.pbest_cost = rastrigin(my_swarm_rastrigin.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_rastrigin.pbest_pos, my_swarm_rastrigin.pbest_cost = P.compute_pbest(my_swarm_rastrigin) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_rastrigin.pbest_cost) < my_swarm_rastrigin.best_cost:
        my_swarm_rastrigin.best_pos, my_swarm_rastrigin.best_cost = my_topology_rastrigin.compute_gbest(my_swarm_rastrigin)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_rastrigin.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rastrigin.velocity = my_topology_rastrigin.compute_velocity(my_swarm_rastrigin)
    my_swarm_rastrigin.position = my_topology_rastrigin.compute_position(my_swarm_rastrigin)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_rastrigin.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_rastrigin.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 0.0009
# Iteracja: 21 | my_swarm.best_cost: 0.0009
# Iteracja: 41 | my_swarm.best_cost: 0.0009
# Iteracja: 61 | my_swarm.best_cost: 0.0009
# Iteracja: 81 | my_swarm.best_cost: 0.0009
# Najlepszy znaleziony koszt: 0.0008
# Najlepsza znaleziona pozycja: [0.00204161 0.00033944]

# %%
def rosenbrock_with_args(x, a, b, c=0):
    f = (a - x[:, 0]) ** 2 + b * (x[:, 1] - x[:, 0] ** 2) ** 2 + c
    return f

# %%
my_topology_rosenbrock = Star()

# %%
x_max = 10 * np.ones(2)
x_min = -1 * x_max
bounds_rosenbrock = (x_min, x_max)
options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}

# %%
my_swarm_rosenbrock = P.create_swarm(n_particles=50, dimensions=10, options=my_options, bounds=bounds)
# Out:
# 2021-06-15 18:39:44,672 - pyswarms.backend.generators - ERROR - Bounds and/or init_pos should be of size (10,)
# Traceback (most recent call last):
#   File "C:\Users\kmat9\anaconda3\lib\site-packages\pyswarms\backend\generators.py", line 81, in generate_swarm
#     pos = center * np.random.uniform(
#   File "mtrand.pyx", line 1121, in numpy.random.mtrand.RandomState.uniform
#   File "_common.pyx", line 541, in numpy.random._common.cont
#   File "_common.pyx", line 458, in numpy.random._common.cont_broadcast_2
#   File "__init__.pxd", line 741, in numpy.PyArray_MultiIterNew3
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-1718244fde16> in <module>
# ----> 1 my_swarm_rosenbrock = P.create_swarm(n_particles=50, dimensions=10, options=my_options, bounds=bounds)
#
# ~\anaconda3\lib\site-packages\pyswarms\backend\generators.py in create_swarm(n_particles, dimensions, discrete, binary, options, bounds, center, init_pos, clamp)
#     234         )
#     235     else:
# --> 236         position = generate_swarm(
#     237             n_particles,
#     238             dimensions,
#
# ~\anaconda3\lib\site-packages\pyswarms\backend\generators.py in generate_swarm(n_particles, dimensions, bounds, center, init_pos)
#      79                 np.array(ub)[np.newaxis, :], n_particles, axis=0
#      80             )
# ---> 81             pos = center * np.random.uniform(
#      82                 low=min_bounds, high=max_bounds, size=(n_particles, dimensions)
#      83             )
#
# mtrand.pyx in numpy.random.mtrand.RandomState.uniform()
#
# _common.pyx in numpy.random._common.cont()
#
# _common.pyx in numpy.random._common.cont_broadcast_2()
#
# __init__.pxd in numpy.PyArray_MultiIterNew3()
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
my_swarm_rosenbrock = P.create_swarm(n_particles=50, dimensions=10, options=my_options, bounds=bounds)
# Out:
# 2021-06-15 18:40:19,793 - pyswarms.backend.generators - ERROR - Bounds and/or init_pos should be of size (10,)
# Traceback (most recent call last):
#   File "C:\Users\kmat9\anaconda3\lib\site-packages\pyswarms\backend\generators.py", line 81, in generate_swarm
#     pos = center * np.random.uniform(
#   File "mtrand.pyx", line 1121, in numpy.random.mtrand.RandomState.uniform
#   File "_common.pyx", line 541, in numpy.random._common.cont
#   File "_common.pyx", line 458, in numpy.random._common.cont_broadcast_2
#   File "__init__.pxd", line 741, in numpy.PyArray_MultiIterNew3
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-1718244fde16> in <module>
# ----> 1 my_swarm_rosenbrock = P.create_swarm(n_particles=50, dimensions=10, options=my_options, bounds=bounds)
#
# ~\anaconda3\lib\site-packages\pyswarms\backend\generators.py in create_swarm(n_particles, dimensions, discrete, binary, options, bounds, center, init_pos, clamp)
#     234         )
#     235     else:
# --> 236         position = generate_swarm(
#     237             n_particles,
#     238             dimensions,
#
# ~\anaconda3\lib\site-packages\pyswarms\backend\generators.py in generate_swarm(n_particles, dimensions, bounds, center, init_pos)
#      79                 np.array(ub)[np.newaxis, :], n_particles, axis=0
#      80             )
# ---> 81             pos = center * np.random.uniform(
#      82                 low=min_bounds, high=max_bounds, size=(n_particles, dimensions)
#      83             )
#
# mtrand.pyx in numpy.random.mtrand.RandomState.uniform()
#
# _common.pyx in numpy.random._common.cont()
#
# _common.pyx in numpy.random._common.cont_broadcast_2()
#
# __init__.pxd in numpy.PyArray_MultiIterNew3()
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
print(x_max)
# Out:
# [10. 10.]

# %%
print(x_min)
# Out:
# [-10. -10.]

# %%
my_swarm_rosenbrock = P.create_swarm(n_particles=50, dimensions=2, options=my_options)

# %%
iterations = 100 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_rosenbrock.current_cost = rosenbrock(my_swarm_rosenbrock.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_rosenbrock.pbest_cost = rosenbrock(my_swarm_rosenbrock.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_rosenbrock.pbest_pos, my_swarm_rosenbrock.pbest_cost = P.compute_pbest(my_swarm_rosenbrock) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_rosenbrock.pbest_cost) < my_swarm_rosenbrock.best_cost:
        my_swarm_rosenbrock.best_pos, my_swarm_rosenbrock.best_cost = my_topology_rosenbrock.compute_gbest(my_swarm_rosenbrock)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_rosenbrock.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rosenbrock.velocity = my_topology_rosenbrock.compute_velocity(my_swarm_rosenbrock)
    my_swarm_rosenbrock.position = my_topology_rosenbrock.compute_position(my_swarm_rosenbrock)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_rosenbrock.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_rosenbrock.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 92.1929
# Iteracja: 21 | my_swarm.best_cost: 23.5658
# Iteracja: 41 | my_swarm.best_cost: 23.4368
# Iteracja: 61 | my_swarm.best_cost: 23.4366
# Iteracja: 81 | my_swarm.best_cost: 23.4366
# Najlepszy znaleziony koszt: 23.4366
# Najlepsza znaleziona pozycja: [0.91915705 0.86182237 0.77100131 0.69536821 0.64753698 0.71695155
#  0.77936077 0.73940779 0.61634992 0.47226783]

# %%
iterations = 100 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_rosenbrock.current_cost = rosenbrock(my_swarm_rosenbrock.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_rosenbrock.pbest_cost = rosenbrock(my_swarm_rosenbrock.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_rosenbrock.pbest_pos, my_swarm_rosenbrock.pbest_cost = P.compute_pbest(my_swarm_rosenbrock) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_rosenbrock.pbest_cost) < my_swarm_rosenbrock.best_cost:
        my_swarm_rosenbrock.best_pos, my_swarm_rosenbrock.best_cost = my_topology_rosenbrock.compute_gbest(my_swarm_rosenbrock)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_rosenbrock.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rosenbrock.velocity = my_topology_rosenbrock.compute_velocity(my_swarm_rosenbrock)
    my_swarm_rosenbrock.position = my_topology_rosenbrock.compute_position(my_swarm_rosenbrock)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_rosenbrock.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_rosenbrock.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 23.4366
# Iteracja: 21 | my_swarm.best_cost: 23.4366
# Iteracja: 41 | my_swarm.best_cost: 23.4366
# Iteracja: 61 | my_swarm.best_cost: 23.4366
# Iteracja: 81 | my_swarm.best_cost: 23.4366
# Najlepszy znaleziony koszt: 23.4366
# Najlepsza znaleziona pozycja: [0.91915705 0.86182237 0.77100131 0.69536821 0.64753698 0.71695155
#  0.77936077 0.73940779 0.61634992 0.47226783]

# %%
iterations = 100 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_rosenbrock.current_cost = rosenbrock(my_swarm_rosenbrock.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_rosenbrock.pbest_cost = rosenbrock(my_swarm_rosenbrock.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_rosenbrock.pbest_pos, my_swarm_rosenbrock.pbest_cost = P.compute_pbest(my_swarm_rosenbrock) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_rosenbrock.pbest_cost) < my_swarm_rosenbrock.best_cost:
        my_swarm_rosenbrock.best_pos, my_swarm_rosenbrock.best_cost = my_topology_rosenbrock.compute_gbest(my_swarm_rosenbrock)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_rosenbrock.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rosenbrock.velocity = my_topology_rosenbrock.compute_velocity(my_swarm_rosenbrock)
    my_swarm_rosenbrock.position = my_topology_rosenbrock.compute_position(my_swarm_rosenbrock)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_rosenbrock.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_rosenbrock.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 23.4366
# Iteracja: 21 | my_swarm.best_cost: 23.4366
# Iteracja: 41 | my_swarm.best_cost: 23.4366
# Iteracja: 61 | my_swarm.best_cost: 23.4366
# Iteracja: 81 | my_swarm.best_cost: 23.4366
# Najlepszy znaleziony koszt: 23.4366
# Najlepsza znaleziona pozycja: [0.91915705 0.86182237 0.77100131 0.69536821 0.64753698 0.71695155
#  0.77936077 0.73940779 0.61634992 0.47226783]

# %%
iterations = 1000
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_rosenbrock.current_cost = rosenbrock(my_swarm_rosenbrock.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_rosenbrock.pbest_cost = rosenbrock(my_swarm_rosenbrock.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_rosenbrock.pbest_pos, my_swarm_rosenbrock.pbest_cost = P.compute_pbest(my_swarm_rosenbrock) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_rosenbrock.pbest_cost) < my_swarm_rosenbrock.best_cost:
        my_swarm_rosenbrock.best_pos, my_swarm_rosenbrock.best_cost = my_topology_rosenbrock.compute_gbest(my_swarm_rosenbrock)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_rosenbrock.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rosenbrock.velocity = my_topology_rosenbrock.compute_velocity(my_swarm_rosenbrock)
    my_swarm_rosenbrock.position = my_topology_rosenbrock.compute_position(my_swarm_rosenbrock)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_rosenbrock.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_rosenbrock.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 23.4366
# Iteracja: 21 | my_swarm.best_cost: 23.4366
# Iteracja: 41 | my_swarm.best_cost: 23.4366
# Iteracja: 61 | my_swarm.best_cost: 23.4366
# Iteracja: 81 | my_swarm.best_cost: 23.4366
# Iteracja: 101 | my_swarm.best_cost: 23.4366
# Iteracja: 121 | my_swarm.best_cost: 23.4366
# Iteracja: 141 | my_swarm.best_cost: 23.4366
# Iteracja: 161 | my_swarm.best_cost: 23.4366
# Iteracja: 181 | my_swarm.best_cost: 23.4366
# Iteracja: 201 | my_swarm.best_cost: 23.4366
# Iteracja: 221 | my_swarm.best_cost: 23.4366
# Iteracja: 241 | my_swarm.best_cost: 23.4366
# Iteracja: 261 | my_swarm.best_cost: 23.4366
# Iteracja: 281 | my_swarm.best_cost: 23.4366
# Iteracja: 301 | my_swarm.best_cost: 23.4366
# Iteracja: 321 | my_swarm.best_cost: 23.4366
# Iteracja: 341 | my_swarm.best_cost: 23.4366
# Iteracja: 361 | my_swarm.best_cost: 23.4366
# Iteracja: 381 | my_swarm.best_cost: 23.4366
# Iteracja: 401 | my_swarm.best_cost: 23.4366
# Iteracja: 421 | my_swarm.best_cost: 23.4366
# Iteracja: 441 | my_swarm.best_cost: 23.4366
# Iteracja: 461 | my_swarm.best_cost: 23.4366
# Iteracja: 481 | my_swarm.best_cost: 23.4366
# Iteracja: 501 | my_swarm.best_cost: 23.4366
# Iteracja: 521 | my_swarm.best_cost: 23.4366
# Iteracja: 541 | my_swarm.best_cost: 23.4366
# Iteracja: 561 | my_swarm.best_cost: 23.4366
# Iteracja: 581 | my_swarm.best_cost: 23.4366
# Iteracja: 601 | my_swarm.best_cost: 23.4366
# Iteracja: 621 | my_swarm.best_cost: 23.4366
# Iteracja: 641 | my_swarm.best_cost: 23.4366
# Iteracja: 661 | my_swarm.best_cost: 23.4366
# Iteracja: 681 | my_swarm.best_cost: 23.4366
# Iteracja: 701 | my_swarm.best_cost: 23.4366
# Iteracja: 721 | my_swarm.best_cost: 23.4366
# Iteracja: 741 | my_swarm.best_cost: 23.4366
# Iteracja: 761 | my_swarm.best_cost: 23.4366
# Iteracja: 781 | my_swarm.best_cost: 23.4366
# Iteracja: 801 | my_swarm.best_cost: 23.4366
# Iteracja: 821 | my_swarm.best_cost: 23.4366
# Iteracja: 841 | my_swarm.best_cost: 23.4366
# Iteracja: 861 | my_swarm.best_cost: 23.4366
# Iteracja: 881 | my_swarm.best_cost: 23.4366
# Iteracja: 901 | my_swarm.best_cost: 23.4366
# Iteracja: 921 | my_swarm.best_cost: 23.4366
# Iteracja: 941 | my_swarm.best_cost: 23.4366
# Iteracja: 961 | my_swarm.best_cost: 23.4366
# Iteracja: 981 | my_swarm.best_cost: 23.4366
# Najlepszy znaleziony koszt: 23.4366
# Najlepsza znaleziona pozycja: [0.91915705 0.86182237 0.77100131 0.69536821 0.64753698 0.71695155
#  0.77936077 0.73940779 0.61634992 0.47226783]

# %%
iterations = 10000 
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_rosenbrock.current_cost = rosenbrock(my_swarm_rosenbrock.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_rosenbrock.pbest_cost = rosenbrock(my_swarm_rosenbrock.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_rosenbrock.pbest_pos, my_swarm_rosenbrock.pbest_cost = P.compute_pbest(my_swarm_rosenbrock) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_rosenbrock.pbest_cost) < my_swarm_rosenbrock.best_cost:
        my_swarm_rosenbrock.best_pos, my_swarm_rosenbrock.best_cost = my_topology_rosenbrock.compute_gbest(my_swarm_rosenbrock)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_rosenbrock.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rosenbrock.velocity = my_topology_rosenbrock.compute_velocity(my_swarm_rosenbrock)
    my_swarm_rosenbrock.position = my_topology_rosenbrock.compute_position(my_swarm_rosenbrock)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_rosenbrock.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_rosenbrock.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 23.4366
# Iteracja: 21 | my_swarm.best_cost: 23.4366
# Iteracja: 41 | my_swarm.best_cost: 23.4366
# Iteracja: 61 | my_swarm.best_cost: 23.4366
# Iteracja: 81 | my_swarm.best_cost: 23.4366
# Iteracja: 101 | my_swarm.best_cost: 23.4366
# Iteracja: 121 | my_swarm.best_cost: 23.4366
# Iteracja: 141 | my_swarm.best_cost: 23.4366
# Iteracja: 161 | my_swarm.best_cost: 23.4366
# Iteracja: 181 | my_swarm.best_cost: 23.4366
# Iteracja: 201 | my_swarm.best_cost: 23.4366
# Iteracja: 221 | my_swarm.best_cost: 23.4366
# Iteracja: 241 | my_swarm.best_cost: 23.4366
# Iteracja: 261 | my_swarm.best_cost: 23.4366
# Iteracja: 281 | my_swarm.best_cost: 23.4366
# Iteracja: 301 | my_swarm.best_cost: 23.4366
# Iteracja: 321 | my_swarm.best_cost: 23.4366
# Iteracja: 341 | my_swarm.best_cost: 23.4366
# Iteracja: 361 | my_swarm.best_cost: 23.4366
# Iteracja: 381 | my_swarm.best_cost: 23.4366
# Iteracja: 401 | my_swarm.best_cost: 23.4366
# Iteracja: 421 | my_swarm.best_cost: 23.4366
# Iteracja: 441 | my_swarm.best_cost: 23.4366
# Iteracja: 461 | my_swarm.best_cost: 23.4366
# Iteracja: 481 | my_swarm.best_cost: 23.4366
# Iteracja: 501 | my_swarm.best_cost: 23.4366
# Iteracja: 521 | my_swarm.best_cost: 23.4366
# Iteracja: 541 | my_swarm.best_cost: 23.4366
# Iteracja: 561 | my_swarm.best_cost: 23.4366
# Iteracja: 581 | my_swarm.best_cost: 23.4366
# Iteracja: 601 | my_swarm.best_cost: 23.4366
# Iteracja: 621 | my_swarm.best_cost: 23.4366
# Iteracja: 641 | my_swarm.best_cost: 23.4366
# Iteracja: 661 | my_swarm.best_cost: 23.4366
# Iteracja: 681 | my_swarm.best_cost: 23.4366
# Iteracja: 701 | my_swarm.best_cost: 23.4366
# Iteracja: 721 | my_swarm.best_cost: 23.4366
# Iteracja: 741 | my_swarm.best_cost: 23.4366
# Iteracja: 761 | my_swarm.best_cost: 23.4366
# Iteracja: 781 | my_swarm.best_cost: 23.4366
# Iteracja: 801 | my_swarm.best_cost: 23.4366
# Iteracja: 821 | my_swarm.best_cost: 23.4366
# Iteracja: 841 | my_swarm.best_cost: 23.4366
# Iteracja: 861 | my_swarm.best_cost: 23.4366
# Iteracja: 881 | my_swarm.best_cost: 23.4366
# Iteracja: 901 | my_swarm.best_cost: 23.4366
# Iteracja: 921 | my_swarm.best_cost: 23.4366
# Iteracja: 941 | my_swarm.best_cost: 23.4366
# Iteracja: 961 | my_swarm.best_cost: 23.4366
# Iteracja: 981 | my_swarm.best_cost: 23.4366
# Iteracja: 1001 | my_swarm.best_cost: 23.4366
# Iteracja: 1021 | my_swarm.best_cost: 23.4366
# Iteracja: 1041 | my_swarm.best_cost: 23.4366
# Iteracja: 1061 | my_swarm.best_cost: 23.4366
# Iteracja: 1081 | my_swarm.best_cost: 23.4366
# Iteracja: 1101 | my_swarm.best_cost: 23.4366
# Iteracja: 1121 | my_swarm.best_cost: 23.4366
# Iteracja: 1141 | my_swarm.best_cost: 23.4366
# Iteracja: 1161 | my_swarm.best_cost: 23.4366
# Iteracja: 1181 | my_swarm.best_cost: 23.4366
# Iteracja: 1201 | my_swarm.best_cost: 23.4366
# Iteracja: 1221 | my_swarm.best_cost: 23.4366
# Iteracja: 1241 | my_swarm.best_cost: 23.4366
# Iteracja: 1261 | my_swarm.best_cost: 23.4366
# Iteracja: 1281 | my_swarm.best_cost: 23.4366
# Iteracja: 1301 | my_swarm.best_cost: 23.4366
# Iteracja: 1321 | my_swarm.best_cost: 23.4366
# Iteracja: 1341 | my_swarm.best_cost: 23.4366
# Iteracja: 1361 | my_swarm.best_cost: 23.4366
# Iteracja: 1381 | my_swarm.best_cost: 23.4366
# Iteracja: 1401 | my_swarm.best_cost: 23.4366
# Iteracja: 1421 | my_swarm.best_cost: 23.4366
# Iteracja: 1441 | my_swarm.best_cost: 23.4366
# Iteracja: 1461 | my_swarm.best_cost: 23.4366
# Iteracja: 1481 | my_swarm.best_cost: 23.4366
# Iteracja: 1501 | my_swarm.best_cost: 23.4366
# Iteracja: 1521 | my_swarm.best_cost: 23.4366
# Iteracja: 1541 | my_swarm.best_cost: 23.4366
# Iteracja: 1561 | my_swarm.best_cost: 23.4366
# Iteracja: 1581 | my_swarm.best_cost: 23.4366
# Iteracja: 1601 | my_swarm.best_cost: 23.4366
# Iteracja: 1621 | my_swarm.best_cost: 23.4366
# Iteracja: 1641 | my_swarm.best_cost: 23.4366
# Iteracja: 1661 | my_swarm.best_cost: 23.4366
# Iteracja: 1681 | my_swarm.best_cost: 23.4366
# Iteracja: 1701 | my_swarm.best_cost: 23.4366
# Iteracja: 1721 | my_swarm.best_cost: 23.4366
# Iteracja: 1741 | my_swarm.best_cost: 23.4366
# Iteracja: 1761 | my_swarm.best_cost: 23.4366
# Iteracja: 1781 | my_swarm.best_cost: 23.4366
# Iteracja: 1801 | my_swarm.best_cost: 23.4366
# Iteracja: 1821 | my_swarm.best_cost: 23.4366
# Iteracja: 1841 | my_swarm.best_cost: 23.4366
# Iteracja: 1861 | my_swarm.best_cost: 23.4366
# Iteracja: 1881 | my_swarm.best_cost: 23.4366
# Iteracja: 1901 | my_swarm.best_cost: 23.4366
# Iteracja: 1921 | my_swarm.best_cost: 23.4366
# Iteracja: 1941 | my_swarm.best_cost: 23.4366
# Iteracja: 1961 | my_swarm.best_cost: 23.4366
# Iteracja: 1981 | my_swarm.best_cost: 23.4366
# Iteracja: 2001 | my_swarm.best_cost: 23.4366
# Iteracja: 2021 | my_swarm.best_cost: 23.4366
# Iteracja: 2041 | my_swarm.best_cost: 23.4366
# Iteracja: 2061 | my_swarm.best_cost: 23.4366
# Iteracja: 2081 | my_swarm.best_cost: 23.4366
# Iteracja: 2101 | my_swarm.best_cost: 23.4366
# Iteracja: 2121 | my_swarm.best_cost: 23.4366
# Iteracja: 2141 | my_swarm.best_cost: 23.4366
# Iteracja: 2161 | my_swarm.best_cost: 23.4366
# Iteracja: 2181 | my_swarm.best_cost: 23.4366
# Iteracja: 2201 | my_swarm.best_cost: 23.4366
# Iteracja: 2221 | my_swarm.best_cost: 23.4366
# Iteracja: 2241 | my_swarm.best_cost: 23.4366
# Iteracja: 2261 | my_swarm.best_cost: 23.4366
# Iteracja: 2281 | my_swarm.best_cost: 23.4366
# Iteracja: 2301 | my_swarm.best_cost: 23.4366
# Iteracja: 2321 | my_swarm.best_cost: 23.4366
# Iteracja: 2341 | my_swarm.best_cost: 23.4366
# Iteracja: 2361 | my_swarm.best_cost: 23.4366
# Iteracja: 2381 | my_swarm.best_cost: 23.4366
# Iteracja: 2401 | my_swarm.best_cost: 23.4366
# Iteracja: 2421 | my_swarm.best_cost: 23.4366
# Iteracja: 2441 | my_swarm.best_cost: 23.4366
# Iteracja: 2461 | my_swarm.best_cost: 23.4366
# Iteracja: 2481 | my_swarm.best_cost: 23.4366
# Iteracja: 2501 | my_swarm.best_cost: 23.4366
# Iteracja: 2521 | my_swarm.best_cost: 23.4366
# Iteracja: 2541 | my_swarm.best_cost: 23.4366
# Iteracja: 2561 | my_swarm.best_cost: 23.4366
# Iteracja: 2581 | my_swarm.best_cost: 23.4366
# Iteracja: 2601 | my_swarm.best_cost: 23.4366
# Iteracja: 2621 | my_swarm.best_cost: 23.4366
# Iteracja: 2641 | my_swarm.best_cost: 23.4366
# Iteracja: 2661 | my_swarm.best_cost: 23.4366
# Iteracja: 2681 | my_swarm.best_cost: 23.4366
# Iteracja: 2701 | my_swarm.best_cost: 23.4366
# Iteracja: 2721 | my_swarm.best_cost: 23.4366
# Iteracja: 2741 | my_swarm.best_cost: 23.4366
# Iteracja: 2761 | my_swarm.best_cost: 23.4366
# Iteracja: 2781 | my_swarm.best_cost: 23.4366
# Iteracja: 2801 | my_swarm.best_cost: 23.4366
# Iteracja: 2821 | my_swarm.best_cost: 23.4366
# Iteracja: 2841 | my_swarm.best_cost: 23.4366
# Iteracja: 2861 | my_swarm.best_cost: 23.4366
# Iteracja: 2881 | my_swarm.best_cost: 23.4366
# Iteracja: 2901 | my_swarm.best_cost: 23.4366
# Iteracja: 2921 | my_swarm.best_cost: 23.4366
# Iteracja: 2941 | my_swarm.best_cost: 23.4366
# Iteracja: 2961 | my_swarm.best_cost: 23.4366
# Iteracja: 2981 | my_swarm.best_cost: 23.4366
# Iteracja: 3001 | my_swarm.best_cost: 23.4366
# Iteracja: 3021 | my_swarm.best_cost: 23.4366
# Iteracja: 3041 | my_swarm.best_cost: 23.4366
# Iteracja: 3061 | my_swarm.best_cost: 23.4366
# Iteracja: 3081 | my_swarm.best_cost: 23.4366
# Iteracja: 3101 | my_swarm.best_cost: 23.4366
# Iteracja: 3121 | my_swarm.best_cost: 23.4366
# Iteracja: 3141 | my_swarm.best_cost: 23.4366
# Iteracja: 3161 | my_swarm.best_cost: 23.4366
# Iteracja: 3181 | my_swarm.best_cost: 23.4366
# Iteracja: 3201 | my_swarm.best_cost: 23.4366
# Iteracja: 3221 | my_swarm.best_cost: 23.4366
# Iteracja: 3241 | my_swarm.best_cost: 23.4366
# Iteracja: 3261 | my_swarm.best_cost: 23.4366
# Iteracja: 3281 | my_swarm.best_cost: 23.4366
# Iteracja: 3301 | my_swarm.best_cost: 23.4366
# Iteracja: 3321 | my_swarm.best_cost: 23.4366
# Iteracja: 3341 | my_swarm.best_cost: 23.4366
# Iteracja: 3361 | my_swarm.best_cost: 23.4366
# Iteracja: 3381 | my_swarm.best_cost: 23.4366
# Iteracja: 3401 | my_swarm.best_cost: 23.4366
# Iteracja: 3421 | my_swarm.best_cost: 23.4366
# Iteracja: 3441 | my_swarm.best_cost: 23.4366
# Iteracja: 3461 | my_swarm.best_cost: 23.4366
# Iteracja: 3481 | my_swarm.best_cost: 23.4366
# Iteracja: 3501 | my_swarm.best_cost: 23.4366
# Iteracja: 3521 | my_swarm.best_cost: 23.4366
# Iteracja: 3541 | my_swarm.best_cost: 23.4366
# Iteracja: 3561 | my_swarm.best_cost: 23.4366
# Iteracja: 3581 | my_swarm.best_cost: 23.4366
# Iteracja: 3601 | my_swarm.best_cost: 23.4366
# Iteracja: 3621 | my_swarm.best_cost: 23.4366
# Iteracja: 3641 | my_swarm.best_cost: 23.4366
# Iteracja: 3661 | my_swarm.best_cost: 23.4366
# Iteracja: 3681 | my_swarm.best_cost: 23.4366
# Iteracja: 3701 | my_swarm.best_cost: 23.4366
# Iteracja: 3721 | my_swarm.best_cost: 23.4366
# Iteracja: 3741 | my_swarm.best_cost: 23.4366
# Iteracja: 3761 | my_swarm.best_cost: 23.4366
# Iteracja: 3781 | my_swarm.best_cost: 23.4366
# Iteracja: 3801 | my_swarm.best_cost: 23.4366
# Iteracja: 3821 | my_swarm.best_cost: 23.4366
# Iteracja: 3841 | my_swarm.best_cost: 23.4366
# Iteracja: 3861 | my_swarm.best_cost: 23.4366
# Iteracja: 3881 | my_swarm.best_cost: 23.4366
# Iteracja: 3901 | my_swarm.best_cost: 23.4366
# Iteracja: 3921 | my_swarm.best_cost: 23.4366
# Iteracja: 3941 | my_swarm.best_cost: 23.4366
# Iteracja: 3961 | my_swarm.best_cost: 23.4366
# Iteracja: 3981 | my_swarm.best_cost: 23.4366
# Iteracja: 4001 | my_swarm.best_cost: 23.4366
# Iteracja: 4021 | my_swarm.best_cost: 23.4366
# Iteracja: 4041 | my_swarm.best_cost: 23.4366
# Iteracja: 4061 | my_swarm.best_cost: 23.4366
# Iteracja: 4081 | my_swarm.best_cost: 23.4366
# Iteracja: 4101 | my_swarm.best_cost: 23.4366
# Iteracja: 4121 | my_swarm.best_cost: 23.4366
# Iteracja: 4141 | my_swarm.best_cost: 23.4366
# Iteracja: 4161 | my_swarm.best_cost: 23.4366
# Iteracja: 4181 | my_swarm.best_cost: 23.4366
# Iteracja: 4201 | my_swarm.best_cost: 23.4366
# Iteracja: 4221 | my_swarm.best_cost: 23.4366
# Iteracja: 4241 | my_swarm.best_cost: 23.4366
# Iteracja: 4261 | my_swarm.best_cost: 23.4366
# Iteracja: 4281 | my_swarm.best_cost: 23.4366
# Iteracja: 4301 | my_swarm.best_cost: 23.4366
# Iteracja: 4321 | my_swarm.best_cost: 23.4366
# Iteracja: 4341 | my_swarm.best_cost: 23.4366
# Iteracja: 4361 | my_swarm.best_cost: 23.4366
# Iteracja: 4381 | my_swarm.best_cost: 23.4366
# Iteracja: 4401 | my_swarm.best_cost: 23.4366
# Iteracja: 4421 | my_swarm.best_cost: 23.4366
# Iteracja: 4441 | my_swarm.best_cost: 23.4366
# Iteracja: 4461 | my_swarm.best_cost: 23.4366
# Iteracja: 4481 | my_swarm.best_cost: 23.4366
# Iteracja: 4501 | my_swarm.best_cost: 23.4366
# Iteracja: 4521 | my_swarm.best_cost: 23.4366
# Iteracja: 4541 | my_swarm.best_cost: 23.4366
# Iteracja: 4561 | my_swarm.best_cost: 23.4366
# Iteracja: 4581 | my_swarm.best_cost: 23.4366
# Iteracja: 4601 | my_swarm.best_cost: 23.4366
# Iteracja: 4621 | my_swarm.best_cost: 23.4366
# Iteracja: 4641 | my_swarm.best_cost: 23.4366
# Iteracja: 4661 | my_swarm.best_cost: 23.4366
# Iteracja: 4681 | my_swarm.best_cost: 23.4366
# Iteracja: 4701 | my_swarm.best_cost: 23.4366
# Iteracja: 4721 | my_swarm.best_cost: 23.4366
# Iteracja: 4741 | my_swarm.best_cost: 23.4366
# Iteracja: 4761 | my_swarm.best_cost: 23.4366
# Iteracja: 4781 | my_swarm.best_cost: 23.4366
# Iteracja: 4801 | my_swarm.best_cost: 23.4366
# Iteracja: 4821 | my_swarm.best_cost: 23.4366
# Iteracja: 4841 | my_swarm.best_cost: 23.4366
# Iteracja: 4861 | my_swarm.best_cost: 23.4366
# Iteracja: 4881 | my_swarm.best_cost: 23.4366
# Iteracja: 4901 | my_swarm.best_cost: 23.4366
# Iteracja: 4921 | my_swarm.best_cost: 23.4366
# Iteracja: 4941 | my_swarm.best_cost: 23.4366
# Iteracja: 4961 | my_swarm.best_cost: 23.4366
# Iteracja: 4981 | my_swarm.best_cost: 23.4366
# Iteracja: 5001 | my_swarm.best_cost: 23.4366
# Iteracja: 5021 | my_swarm.best_cost: 23.4366
# Iteracja: 5041 | my_swarm.best_cost: 23.4366
# Iteracja: 5061 | my_swarm.best_cost: 23.4366
# Iteracja: 5081 | my_swarm.best_cost: 23.4366
# Iteracja: 5101 | my_swarm.best_cost: 23.4366
# Iteracja: 5121 | my_swarm.best_cost: 23.4366
# Iteracja: 5141 | my_swarm.best_cost: 23.4366
# Iteracja: 5161 | my_swarm.best_cost: 23.4366
# Iteracja: 5181 | my_swarm.best_cost: 23.4366
# Iteracja: 5201 | my_swarm.best_cost: 23.4366
# Iteracja: 5221 | my_swarm.best_cost: 23.4366
# Iteracja: 5241 | my_swarm.best_cost: 23.4366
# Iteracja: 5261 | my_swarm.best_cost: 23.4366
# Iteracja: 5281 | my_swarm.best_cost: 23.4366
# Iteracja: 5301 | my_swarm.best_cost: 23.4366
# Iteracja: 5321 | my_swarm.best_cost: 23.4366
# Iteracja: 5341 | my_swarm.best_cost: 23.4366
# Iteracja: 5361 | my_swarm.best_cost: 23.4366
# Iteracja: 5381 | my_swarm.best_cost: 23.4366
# Iteracja: 5401 | my_swarm.best_cost: 23.4366
# Iteracja: 5421 | my_swarm.best_cost: 23.4366
# Iteracja: 5441 | my_swarm.best_cost: 23.4366
# Iteracja: 5461 | my_swarm.best_cost: 23.4366
# Iteracja: 5481 | my_swarm.best_cost: 23.4366
# Iteracja: 5501 | my_swarm.best_cost: 23.4366
# Iteracja: 5521 | my_swarm.best_cost: 23.4366
# Iteracja: 5541 | my_swarm.best_cost: 23.4366
# Iteracja: 5561 | my_swarm.best_cost: 23.4366
# Iteracja: 5581 | my_swarm.best_cost: 23.4366
# Iteracja: 5601 | my_swarm.best_cost: 23.4366
# Iteracja: 5621 | my_swarm.best_cost: 23.4366
# Iteracja: 5641 | my_swarm.best_cost: 23.4366
# Iteracja: 5661 | my_swarm.best_cost: 23.4366
# Iteracja: 5681 | my_swarm.best_cost: 23.4366
# Iteracja: 5701 | my_swarm.best_cost: 23.4366
# Iteracja: 5721 | my_swarm.best_cost: 23.4366
# Iteracja: 5741 | my_swarm.best_cost: 23.4366
# Iteracja: 5761 | my_swarm.best_cost: 23.4366
# Iteracja: 5781 | my_swarm.best_cost: 23.4366
# Iteracja: 5801 | my_swarm.best_cost: 23.4366
# Iteracja: 5821 | my_swarm.best_cost: 23.4366
# Iteracja: 5841 | my_swarm.best_cost: 23.4366
# Iteracja: 5861 | my_swarm.best_cost: 23.4366
# Iteracja: 5881 | my_swarm.best_cost: 23.4366
# Iteracja: 5901 | my_swarm.best_cost: 23.4366
# Iteracja: 5921 | my_swarm.best_cost: 23.4366
# Iteracja: 5941 | my_swarm.best_cost: 23.4366
# Iteracja: 5961 | my_swarm.best_cost: 23.4366
# Iteracja: 5981 | my_swarm.best_cost: 23.4366
# Iteracja: 6001 | my_swarm.best_cost: 23.4366
# Iteracja: 6021 | my_swarm.best_cost: 23.4366
# Iteracja: 6041 | my_swarm.best_cost: 23.4366
# Iteracja: 6061 | my_swarm.best_cost: 23.4366
# Iteracja: 6081 | my_swarm.best_cost: 23.4366
# Iteracja: 6101 | my_swarm.best_cost: 23.4366
# Iteracja: 6121 | my_swarm.best_cost: 23.4366
# Iteracja: 6141 | my_swarm.best_cost: 23.4366
# Iteracja: 6161 | my_swarm.best_cost: 23.4366
# Iteracja: 6181 | my_swarm.best_cost: 23.4366
# Iteracja: 6201 | my_swarm.best_cost: 23.4366
# Iteracja: 6221 | my_swarm.best_cost: 23.4366
# Iteracja: 6241 | my_swarm.best_cost: 23.4366
# Iteracja: 6261 | my_swarm.best_cost: 23.4366
# Iteracja: 6281 | my_swarm.best_cost: 23.4366
# Iteracja: 6301 | my_swarm.best_cost: 23.4366
# Iteracja: 6321 | my_swarm.best_cost: 23.4366
# Iteracja: 6341 | my_swarm.best_cost: 23.4366
# Iteracja: 6361 | my_swarm.best_cost: 23.4366
# Iteracja: 6381 | my_swarm.best_cost: 23.4366
# Iteracja: 6401 | my_swarm.best_cost: 23.4366
# Iteracja: 6421 | my_swarm.best_cost: 23.4366
# Iteracja: 6441 | my_swarm.best_cost: 23.4366
# Iteracja: 6461 | my_swarm.best_cost: 23.4366
# Iteracja: 6481 | my_swarm.best_cost: 23.4366
# Iteracja: 6501 | my_swarm.best_cost: 23.4366
# Iteracja: 6521 | my_swarm.best_cost: 23.4366
# Iteracja: 6541 | my_swarm.best_cost: 23.4366
# Iteracja: 6561 | my_swarm.best_cost: 23.4366
# Iteracja: 6581 | my_swarm.best_cost: 23.4366
# Iteracja: 6601 | my_swarm.best_cost: 23.4366
# Iteracja: 6621 | my_swarm.best_cost: 23.4366
# Iteracja: 6641 | my_swarm.best_cost: 23.4366
# Iteracja: 6661 | my_swarm.best_cost: 23.4366
# Iteracja: 6681 | my_swarm.best_cost: 23.4366
# Iteracja: 6701 | my_swarm.best_cost: 23.4366
# Iteracja: 6721 | my_swarm.best_cost: 23.4366
# Iteracja: 6741 | my_swarm.best_cost: 23.4366
# Iteracja: 6761 | my_swarm.best_cost: 23.4366
# Iteracja: 6781 | my_swarm.best_cost: 23.4366
# Iteracja: 6801 | my_swarm.best_cost: 23.4366
# Iteracja: 6821 | my_swarm.best_cost: 23.4366
# Iteracja: 6841 | my_swarm.best_cost: 23.4366
# Iteracja: 6861 | my_swarm.best_cost: 23.4366
# Iteracja: 6881 | my_swarm.best_cost: 23.4366
# Iteracja: 6901 | my_swarm.best_cost: 23.4366
# Iteracja: 6921 | my_swarm.best_cost: 23.4366
# Iteracja: 6941 | my_swarm.best_cost: 23.4366
# Iteracja: 6961 | my_swarm.best_cost: 23.4366
# Iteracja: 6981 | my_swarm.best_cost: 23.4366
# Iteracja: 7001 | my_swarm.best_cost: 23.4366
# Iteracja: 7021 | my_swarm.best_cost: 23.4366
# Iteracja: 7041 | my_swarm.best_cost: 23.4366
# Iteracja: 7061 | my_swarm.best_cost: 23.4366
# Iteracja: 7081 | my_swarm.best_cost: 23.4366
# Iteracja: 7101 | my_swarm.best_cost: 23.4366
# Iteracja: 7121 | my_swarm.best_cost: 23.4366
# Iteracja: 7141 | my_swarm.best_cost: 23.4366
# Iteracja: 7161 | my_swarm.best_cost: 23.4366
# Iteracja: 7181 | my_swarm.best_cost: 23.4366
# Iteracja: 7201 | my_swarm.best_cost: 23.4366
# Iteracja: 7221 | my_swarm.best_cost: 23.4366
# Iteracja: 7241 | my_swarm.best_cost: 23.4366
# Iteracja: 7261 | my_swarm.best_cost: 23.4366
# Iteracja: 7281 | my_swarm.best_cost: 23.4366
# Iteracja: 7301 | my_swarm.best_cost: 23.4366
# Iteracja: 7321 | my_swarm.best_cost: 23.4366
# Iteracja: 7341 | my_swarm.best_cost: 23.4366
# Iteracja: 7361 | my_swarm.best_cost: 23.4366
# Iteracja: 7381 | my_swarm.best_cost: 23.4366
# Iteracja: 7401 | my_swarm.best_cost: 23.4366
# Iteracja: 7421 | my_swarm.best_cost: 23.4366
# Iteracja: 7441 | my_swarm.best_cost: 23.4366
# Iteracja: 7461 | my_swarm.best_cost: 23.4366
# Iteracja: 7481 | my_swarm.best_cost: 23.4366
# Iteracja: 7501 | my_swarm.best_cost: 23.4366
# Iteracja: 7521 | my_swarm.best_cost: 23.4366
# Iteracja: 7541 | my_swarm.best_cost: 23.4366
# Iteracja: 7561 | my_swarm.best_cost: 23.4366
# Iteracja: 7581 | my_swarm.best_cost: 23.4366
# Iteracja: 7601 | my_swarm.best_cost: 23.4366
# Iteracja: 7621 | my_swarm.best_cost: 23.4366
# Iteracja: 7641 | my_swarm.best_cost: 23.4366
# Iteracja: 7661 | my_swarm.best_cost: 23.4366
# Iteracja: 7681 | my_swarm.best_cost: 23.4366
# Iteracja: 7701 | my_swarm.best_cost: 23.4366
# Iteracja: 7721 | my_swarm.best_cost: 23.4366
# Iteracja: 7741 | my_swarm.best_cost: 23.4366
# Iteracja: 7761 | my_swarm.best_cost: 23.4366
# Iteracja: 7781 | my_swarm.best_cost: 23.4366
# Iteracja: 7801 | my_swarm.best_cost: 23.4366
# Iteracja: 7821 | my_swarm.best_cost: 23.4366
# Iteracja: 7841 | my_swarm.best_cost: 23.4366
# Iteracja: 7861 | my_swarm.best_cost: 23.4366
# Iteracja: 7881 | my_swarm.best_cost: 23.4366
# Iteracja: 7901 | my_swarm.best_cost: 23.4366
# Iteracja: 7921 | my_swarm.best_cost: 23.4366
# Iteracja: 7941 | my_swarm.best_cost: 23.4366
# Iteracja: 7961 | my_swarm.best_cost: 23.4366
# Iteracja: 7981 | my_swarm.best_cost: 23.4366
# Iteracja: 8001 | my_swarm.best_cost: 23.4366
# Iteracja: 8021 | my_swarm.best_cost: 23.4366
# Iteracja: 8041 | my_swarm.best_cost: 23.4366
# Iteracja: 8061 | my_swarm.best_cost: 23.4366
# Iteracja: 8081 | my_swarm.best_cost: 23.4366
# Iteracja: 8101 | my_swarm.best_cost: 23.4366
# Iteracja: 8121 | my_swarm.best_cost: 23.4366
# Iteracja: 8141 | my_swarm.best_cost: 23.4366
# Iteracja: 8161 | my_swarm.best_cost: 23.4366
# Iteracja: 8181 | my_swarm.best_cost: 23.4366
# Iteracja: 8201 | my_swarm.best_cost: 23.4366
# Iteracja: 8221 | my_swarm.best_cost: 23.4366
# Iteracja: 8241 | my_swarm.best_cost: 23.4366
# Iteracja: 8261 | my_swarm.best_cost: 23.4366
# Iteracja: 8281 | my_swarm.best_cost: 23.4366
# Iteracja: 8301 | my_swarm.best_cost: 23.4366
# Iteracja: 8321 | my_swarm.best_cost: 23.4366
# Iteracja: 8341 | my_swarm.best_cost: 23.4366
# Iteracja: 8361 | my_swarm.best_cost: 23.4366
# Iteracja: 8381 | my_swarm.best_cost: 23.4366
# Iteracja: 8401 | my_swarm.best_cost: 23.4366
# Iteracja: 8421 | my_swarm.best_cost: 23.4366
# Iteracja: 8441 | my_swarm.best_cost: 23.4366
# Iteracja: 8461 | my_swarm.best_cost: 23.4366
# Iteracja: 8481 | my_swarm.best_cost: 23.4366
# Iteracja: 8501 | my_swarm.best_cost: 23.4366
# Iteracja: 8521 | my_swarm.best_cost: 23.4366
# Iteracja: 8541 | my_swarm.best_cost: 23.4366
# Iteracja: 8561 | my_swarm.best_cost: 23.4366
# Iteracja: 8581 | my_swarm.best_cost: 23.4366
# Iteracja: 8601 | my_swarm.best_cost: 23.4366
# Iteracja: 8621 | my_swarm.best_cost: 23.4366
# Iteracja: 8641 | my_swarm.best_cost: 23.4366
# Iteracja: 8661 | my_swarm.best_cost: 23.4366
# Iteracja: 8681 | my_swarm.best_cost: 23.4366
# Iteracja: 8701 | my_swarm.best_cost: 23.4366
# Iteracja: 8721 | my_swarm.best_cost: 23.4366
# Iteracja: 8741 | my_swarm.best_cost: 23.4366
# Iteracja: 8761 | my_swarm.best_cost: 23.4366
# Iteracja: 8781 | my_swarm.best_cost: 23.4366
# Iteracja: 8801 | my_swarm.best_cost: 23.4366
# Iteracja: 8821 | my_swarm.best_cost: 23.4366
# Iteracja: 8841 | my_swarm.best_cost: 23.4366
# Iteracja: 8861 | my_swarm.best_cost: 23.4366
# Iteracja: 8881 | my_swarm.best_cost: 23.4366
# Iteracja: 8901 | my_swarm.best_cost: 23.4366
# Iteracja: 8921 | my_swarm.best_cost: 23.4366
# Iteracja: 8941 | my_swarm.best_cost: 23.4366
# Iteracja: 8961 | my_swarm.best_cost: 23.4366
# Iteracja: 8981 | my_swarm.best_cost: 23.4366
# Iteracja: 9001 | my_swarm.best_cost: 23.4366
# Iteracja: 9021 | my_swarm.best_cost: 23.4366
# Iteracja: 9041 | my_swarm.best_cost: 23.4366
# Iteracja: 9061 | my_swarm.best_cost: 23.4366
# Iteracja: 9081 | my_swarm.best_cost: 23.4366
# Iteracja: 9101 | my_swarm.best_cost: 23.4366
# Iteracja: 9121 | my_swarm.best_cost: 23.4366
# Iteracja: 9141 | my_swarm.best_cost: 23.4366
# Iteracja: 9161 | my_swarm.best_cost: 23.4366
# Iteracja: 9181 | my_swarm.best_cost: 23.4366
# Iteracja: 9201 | my_swarm.best_cost: 23.4366
# Iteracja: 9221 | my_swarm.best_cost: 23.4366
# Iteracja: 9241 | my_swarm.best_cost: 23.4366
# Iteracja: 9261 | my_swarm.best_cost: 23.4366
# Iteracja: 9281 | my_swarm.best_cost: 23.4366
# Iteracja: 9301 | my_swarm.best_cost: 23.4366
# Iteracja: 9321 | my_swarm.best_cost: 23.4366
# Iteracja: 9341 | my_swarm.best_cost: 23.4366
# Iteracja: 9361 | my_swarm.best_cost: 23.4366
# Iteracja: 9381 | my_swarm.best_cost: 23.4366
# Iteracja: 9401 | my_swarm.best_cost: 23.4366
# Iteracja: 9421 | my_swarm.best_cost: 23.4366
# Iteracja: 9441 | my_swarm.best_cost: 23.4366
# Iteracja: 9461 | my_swarm.best_cost: 23.4366
# Iteracja: 9481 | my_swarm.best_cost: 23.4366
# Iteracja: 9501 | my_swarm.best_cost: 23.4366
# Iteracja: 9521 | my_swarm.best_cost: 23.4366
# Iteracja: 9541 | my_swarm.best_cost: 23.4366
# Iteracja: 9561 | my_swarm.best_cost: 23.4366
# Iteracja: 9581 | my_swarm.best_cost: 23.4366
# Iteracja: 9601 | my_swarm.best_cost: 23.4366
# Iteracja: 9621 | my_swarm.best_cost: 23.4366
# Iteracja: 9641 | my_swarm.best_cost: 23.4366
# Iteracja: 9661 | my_swarm.best_cost: 23.4366
# Iteracja: 9681 | my_swarm.best_cost: 23.4366
# Iteracja: 9701 | my_swarm.best_cost: 23.4366
# Iteracja: 9721 | my_swarm.best_cost: 23.4366
# Iteracja: 9741 | my_swarm.best_cost: 23.4366
# Iteracja: 9761 | my_swarm.best_cost: 23.4366
# Iteracja: 9781 | my_swarm.best_cost: 23.4366
# Iteracja: 9801 | my_swarm.best_cost: 23.4366
# Iteracja: 9821 | my_swarm.best_cost: 23.4366
# Iteracja: 9841 | my_swarm.best_cost: 23.4366
# Iteracja: 9861 | my_swarm.best_cost: 23.4366
# Iteracja: 9881 | my_swarm.best_cost: 23.4366
# Iteracja: 9901 | my_swarm.best_cost: 23.4366
# Iteracja: 9921 | my_swarm.best_cost: 23.4366
# Iteracja: 9941 | my_swarm.best_cost: 23.4366
# Iteracja: 9961 | my_swarm.best_cost: 23.4366
# Iteracja: 9981 | my_swarm.best_cost: 23.4366
# Najlepszy znaleziony koszt: 23.4366
# Najlepsza znaleziona pozycja: [0.91915705 0.86182237 0.77100131 0.69536821 0.64753698 0.71695155
#  0.77936077 0.73940779 0.61634992 0.47226783]

# %%
my_swarm_rosenbrock = P.create_swarm(n_particles=50, dimensions=2, options=my_options)

# %%
iterations = 100
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_rosenbrock.current_cost = rosenbrock(my_swarm_rosenbrock.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_rosenbrock.pbest_cost = rosenbrock(my_swarm_rosenbrock.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_rosenbrock.pbest_pos, my_swarm_rosenbrock.pbest_cost = P.compute_pbest(my_swarm_rosenbrock) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_rosenbrock.pbest_cost) < my_swarm_rosenbrock.best_cost:
        my_swarm_rosenbrock.best_pos, my_swarm_rosenbrock.best_cost = my_topology_rosenbrock.compute_gbest(my_swarm_rosenbrock)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_rosenbrock.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rosenbrock.velocity = my_topology_rosenbrock.compute_velocity(my_swarm_rosenbrock)
    my_swarm_rosenbrock.position = my_topology_rosenbrock.compute_position(my_swarm_rosenbrock)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_rosenbrock.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_rosenbrock.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 0.3748
# Iteracja: 21 | my_swarm.best_cost: 0.0012
# Iteracja: 41 | my_swarm.best_cost: 0.0011
# Iteracja: 61 | my_swarm.best_cost: 0.0011
# Iteracja: 81 | my_swarm.best_cost: 0.0011
# Najlepszy znaleziony koszt: 0.0011
# Najlepsza znaleziona pozycja: [0.96677704 0.93457949]

# %%
my_topology_Ackley = Star()

# %%
max_bound_Ackley = 5 * np.ones(2)
min_bound_Ackley = - max_bound_Ackley
bounds_Ackley = (min_bound_Ackley, max_bound_Ackley)

# %%
my_options_Ackley = {'c1': 0.9, 'c2': 0.3, 'w': 0.4}

# %%
my_swarm_Ackley = P.create_swarm(n_particles=50, dimensions=2, options=my_options_Ackley, bounds=bounds_Ackley)

# %%
iterations = 100
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_Ackley.current_cost = ackley(my_swarm_Ackley.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_Ackley.pbest_cost = ackley(my_swarm_Ackley.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_Ackley.pbest_pos, my_swarm_Ackley.pbest_cost = P.compute_pbest(my_swarm_Ackley) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_Ackley.pbest_cost) < my_swarm_Ackley.best_cost:
        my_swarm_Ackley.best_pos, my_swarm_Ackley.best_cost = my_topology_Ackley.compute_gbest(my_swarm_Ackley)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_Ackley.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rosenbrock.velocity = my_topology_Ackley.compute_velocity(my_swarm_Ackley)
    my_swarm_rosenbrock.position = my_topology_Ackley.compute_position(my_swarm_Ackley)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_Ackley.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_Ackley.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 1.2403
# Iteracja: 21 | my_swarm.best_cost: 1.2403
# Iteracja: 41 | my_swarm.best_cost: 1.2403
# Iteracja: 61 | my_swarm.best_cost: 1.2403
# Iteracja: 81 | my_swarm.best_cost: 1.2403
# Najlepszy znaleziony koszt: 1.2403
# Najlepsza znaleziona pozycja: [-0.13052397  0.12817194]

# %%
iterations = 100
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_Ackley.current_cost = ackley(my_swarm_Ackley.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_Ackley.pbest_cost = ackley(my_swarm_Ackley.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_Ackley.pbest_pos, my_swarm_Ackley.pbest_cost = P.compute_pbest(my_swarm_Ackley) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_Ackley.pbest_cost) < my_swarm_Ackley.best_cost:
        my_swarm_Ackley.best_pos, my_swarm_Ackley.best_cost = my_topology_Ackley.compute_gbest(my_swarm_Ackley)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_Ackley.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rosenbrock.velocity = my_topology_Ackley.compute_velocity(my_swarm_Ackley)
    my_swarm_rosenbrock.position = my_topology_Ackley.compute_position(my_swarm_Ackley)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_Ackley.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_Ackley.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 1.5590
# Iteracja: 21 | my_swarm.best_cost: 1.5590
# Iteracja: 41 | my_swarm.best_cost: 1.5590
# Iteracja: 61 | my_swarm.best_cost: 1.5590
# Iteracja: 81 | my_swarm.best_cost: 1.5590
# Najlepszy znaleziony koszt: 1.5590
# Najlepsza znaleziona pozycja: [-0.21820178  0.04745513]

# %%
iterations = 100
for i in range(iterations):
    # aktualizacja najlepszego minimum lokalnego jakie znalazła czastka 
    my_swarm_Ackley.current_cost = ackley(my_swarm_Ackley.position) # obliczenie obecnego kosztu kosztu (wartosc funkcji celu)
    my_swarm_Ackley.pbest_cost = ackley(my_swarm_Ackley.pbest_pos)  # obliczenie najlepszej lokalnej  pozycji
    my_swarm_Ackley.pbest_pos, my_swarm_Ackley.pbest_cost = P.compute_pbest(my_swarm_Ackley) # przypisanie 

    # aktualizacja najlepszego globalnego
    # obliczenie gbest jest zależne od naszej topologii (w naszym wypadku gwiazda)
    if np.min(my_swarm_Ackley.pbest_cost) < my_swarm_Ackley.best_cost:
        my_swarm_Ackley.best_pos, my_swarm_Ackley.best_cost = my_topology_Ackley.compute_gbest(my_swarm_Ackley)

    
    if i%20==0:
        print('Iteracja: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm_Ackley.best_cost))

    # aktualizacja wektorow pozycji i predkosci, zalezne od topologii
    my_swarm_rosenbrock.velocity = my_topology_Ackley.compute_velocity(my_swarm_Ackley)
    my_swarm_rosenbrock.position = my_topology_Ackley.compute_position(my_swarm_Ackley)

print('Najlepszy znaleziony koszt: {:.4f}'.format(my_swarm_Ackley.best_cost))
print('Najlepsza znaleziona pozycja: {}'.format(my_swarm_Ackley.best_pos))
# Out:
# Iteracja: 1 | my_swarm.best_cost: 3.2272
# Iteracja: 21 | my_swarm.best_cost: 3.2272
# Iteracja: 41 | my_swarm.best_cost: 3.2272
# Iteracja: 61 | my_swarm.best_cost: 3.2272
# Iteracja: 81 | my_swarm.best_cost: 3.2272
# Najlepszy znaleziony koszt: 3.2272
# Najlepsza znaleziona pozycja: [-0.72352724  0.07104326]
